# %%
from google.colab import drive
drive.mount('/content/drive')
#!python -m surveillance train --epochs 500
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/dev/surveillance/
# !git clone https://github.com/fsotosan/surveillance
# Out:
# /content/drive/MyDrive/dev/surveillance
# Cloning into 'surveillance'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 26 (delta 6), reused 26 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 15.14 KiB | 344.00 KiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd /content/drive/MyDrive/dev/surveillance/surveillance/
# !pip install -r requirements.txt
# %env SURVEILLANCE_TRAINING_IMAGES=../images
# %env SURVEILLANCE_TRAINING_DB=../db/training.db
# !python -m surveillance train --epochs 500
# Out:
# /content/drive/MyDrive/dev/surveillance/surveillance
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.5 MB/s eta 0:00:0000:01
# ...
# env: SURVEILLANCE_TRAINING_IMAGES=../images
# env: SURVEILLANCE_TRAINING_DB=../db/training.db
# 2026-05-16 16:42:53,421 [INFO] surveillance.train_action: Training set: 1291 images, 7 classes: ['abuelita', 'alexandra', 'dani', 'fernando', 'fraguel', 'lissy', 'mateo']
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/drive/MyDrive/dev/surveillance/surveillance/surveillance/__main__.py", line 4, in <module>
#     main()
#   File "/content/drive/MyDrive/dev/surveillance/surveillance/surveillance/cli.py", line 50, in main
#     sys.exit(run_train(epochs=args.epochs, imgsz=args.imgsz, batch=args.batch,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
